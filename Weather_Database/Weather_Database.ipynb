# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | mbarara
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | dingtao
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | ojitlan
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | pangnirtung
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | tias
# Processing Record 15 of Set 1 | buzmeyin
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | whitehorse
# Processing Record 24 of Set 1 | samarai
# Processing Record 25 of Set 1 | vrangel
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | erzin
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | lorengau
# Processing Record 37 of Set 1 | poum
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | kewanee
# Processing Record 42 of Set 1 | gigmoto
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | tottori
# Processing Record 45 of Set 1 | villa carlos paz
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | rockland
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | ambovombe
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | isangel
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | taltal
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | mahajanga
# Processing Record 8 of Set 2 | taicheng
# Processing Record 9 of Set 2 | husavik
# Processing Record 10 of Set 2 | vazante
# Processing Record 11 of Set 2 | byron bay
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | songjianghe
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | mayo
# Processing Record 18 of Set 2 | san quintin
# Processing Record 19 of Set 2 | mumford
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | faya
# Processing Record 22 of Set 2 | champerico
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | san cristobal
# Processing Record 30 of Set 2 | ostrovnoy
# Processing Record 31 of Set 2 | arlit
# Processing Record 32 of Set 2 | dubti
# Processing Record 33 of Set 2 | alofi
# Processing Record 34 of Set 2 | berlevag
# Processing Record 35 of Set 2 | calabozo
# Processing Record 36 of Set 2 | phan thiet
# Processing Record 37 of Set 2 | oneonta
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | takoradi
# Processing Record 44 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | santa barbara
# Processing Record 47 of Set 2 | luderitz
# Processing Record 48 of Set 2 | garowe
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | antofagasta
# Processing Record 2 of Set 3 | hit
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | chiredzi
# Processing Record 5 of Set 3 | tshikapa
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 3 | sisimiut
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | ahipara
# Processing Record 17 of Set 3 | marathopolis
# City not found. Skipping...
# Processing Record 18 of Set 3 | kimbe
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | petropavlovka
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | urdoma
# Processing Record 24 of Set 3 | ulaangom
# Processing Record 25 of Set 3 | shimoda
# Processing Record 26 of Set 3 | umm kaddadah
# Processing Record 27 of Set 3 | lethem
# Processing Record 28 of Set 3 | college
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | moron
# Processing Record 31 of Set 3 | henties bay
# Processing Record 32 of Set 3 | buraydah
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | araguatins
# City not found. Skipping...
# Processing Record 35 of Set 3 | cabedelo
# Processing Record 36 of Set 3 | bogande
# Processing Record 37 of Set 3 | lata
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | dutlwe
# Processing Record 40 of Set 3 | krasnogvardeyskiy
# Processing Record 41 of Set 3 | maunabo
# Processing Record 42 of Set 3 | rawson
# Processing Record 43 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 3 | nibbar
# Processing Record 45 of Set 3 | haines junction
# Processing Record 46 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 3 | beira
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | santa isabel
# Processing Record 4 of Set 4 | butaritari
# Processing Record 5 of Set 4 | beringovskiy
# Processing Record 6 of Set 4 | pundaguitan
# Processing Record 7 of Set 4 | muyezerskiy
# Processing Record 8 of Set 4 | katete
# Processing Record 9 of Set 4 | wanning
# Processing Record 10 of Set 4 | krasnorechenskiy
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | nova olimpia
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | cheb
# Processing Record 16 of Set 4 | saint-francois
# Processing Record 17 of Set 4 | lensk
# Processing Record 18 of Set 4 | comodoro rivadavia
# Processing Record 19 of Set 4 | nhulunbuy
# Processing Record 20 of Set 4 | bucerias
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | marsh harbour
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | oktyabrskoye
# Processing Record 25 of Set 4 | cabra
# Processing Record 26 of Set 4 | olafsvik
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | pitea
# Processing Record 29 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 30 of Set 4 | lufilufi
# Processing Record 31 of Set 4 | sao felix do xingu
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | casper
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | coahuayana
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | raja sansi
# Processing Record 42 of Set 4 | asosa
# Processing Record 43 of Set 4 | la ronge
# Processing Record 44 of Set 4 | quelimane
# Processing Record 45 of Set 4 | usinsk
# Processing Record 46 of Set 4 | yar-sale
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | raudeberg
# Processing Record 49 of Set 4 | katima mulilo
# Processing Record 50 of Set 4 | tukrah
# Processing Record 1 of Set 5 | santiago
# Processing Record 2 of Set 5 | richards bay
# Processing Record 3 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 4 of Set 5 | karratha
# Processing Record 5 of Set 5 | tamandare
# Processing Record 6 of Set 5 | fare
# Processing Record 7 of Set 5 | gat
# Processing Record 8 of Set 5 | nerang
# Processing Record 9 of Set 5 | rundu
# Processing Record 10 of Set 5 | tornio
# Processing Record 11 of Set 5 | tupik
# Processing Record 12 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 5 | danilov
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | kismayo
# Processing Record 17 of Set 5 | sidi bin nur
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | maceio
# Processing Record 20 of Set 5 | adrar
# Processing Record 21 of Set 5 | zarinsk
# Processing Record 22 of Set 5 | hirara
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | anchorage
# Processing Record 25 of Set 5 | tautira
# Processing Record 26 of Set 5 | banff
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | northam
# Processing Record 29 of Set 5 | riyadh
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | aklavik
# Processing Record 34 of Set 5 | ulladulla
# Processing Record 35 of Set 5 | bitung
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | artigas
# Processing Record 38 of Set 5 | qianan
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | kota kinabalu
# Processing Record 42 of Set 5 | loa janan
# Processing Record 43 of Set 5 | sandhaven
# City not found. Skipping...
# Processing Record 44 of Set 5 | russell
# Processing Record 45 of Set 5 | kaeo
# Processing Record 46 of Set 5 | kilimatinde
# Processing Record 47 of Set 5 | feldbach
# Processing Record 48 of Set 5 | kruisfontein
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | kaitangata
# Processing Record 1 of Set 6 | balaipungut
# Processing Record 2 of Set 6 | santa cruz
# Processing Record 3 of Set 6 | kallaste
# Processing Record 4 of Set 6 | onega
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | ishinomaki
# Processing Record 7 of Set 6 | smithers
# Processing Record 8 of Set 6 | mizdah
# Processing Record 9 of Set 6 | rio gallegos
# Processing Record 10 of Set 6 | san jeronimo
# Processing Record 11 of Set 6 | gayeri
# Processing Record 12 of Set 6 | taunggyi
# Processing Record 13 of Set 6 | staraya kulatka
# Processing Record 14 of Set 6 | semey
# Processing Record 15 of Set 6 | kamyshevatskaya
# Processing Record 16 of Set 6 | almenevo
# City not found. Skipping...
# Processing Record 17 of Set 6 | pevek
# Processing Record 18 of Set 6 | tessalit
# Processing Record 19 of Set 6 | mudgee
# Processing Record 20 of Set 6 | malanje
# Processing Record 21 of Set 6 | provideniya
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | hualmay
# Processing Record 24 of Set 6 | lac du bonnet
# Processing Record 25 of Set 6 | vondrozo
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | saint-georges
# Processing Record 28 of Set 6 | sal rei
# Processing Record 29 of Set 6 | kundiawa
# Processing Record 30 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | skjervoy
# Processing Record 33 of Set 6 | lebu
# Processing Record 34 of Set 6 | novyy urengoy
# Processing Record 35 of Set 6 | talara
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | tawau
# Processing Record 38 of Set 6 | hobyo
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | mareeba
# Processing Record 41 of Set 6 | upington
# Processing Record 42 of Set 6 | port elizabeth
# Processing Record 43 of Set 6 | udachnyy
# Processing Record 44 of Set 6 | abalak
# Processing Record 45 of Set 6 | muros
# Processing Record 46 of Set 6 | tarrafal
# Processing Record 47 of Set 6 | piacabucu
# Processing Record 48 of Set 6 | seoul
# Processing Record 49 of Set 6 | hered
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | pisco
# Processing Record 2 of Set 7 | marawi
# Processing Record 3 of Set 7 | khasan
# Processing Record 4 of Set 7 | ambalavao
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | tikrit
# Processing Record 7 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 7 | volga
# Processing Record 9 of Set 7 | gorontalo
# Processing Record 10 of Set 7 | katobu
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | mackay
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | vanavara
# Processing Record 15 of Set 7 | port blair
# Processing Record 16 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | alberton
# Processing Record 19 of Set 7 | las navas
# Processing Record 20 of Set 7 | ashqelon
# Processing Record 21 of Set 7 | zeya
# Processing Record 22 of Set 7 | saint-augustin
# Processing Record 23 of Set 7 | la tuque
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | svetlogorsk
# Processing Record 27 of Set 7 | vadgaon
# Processing Record 28 of Set 7 | bathsheba
# Processing Record 29 of Set 7 | kargasok
# Processing Record 30 of Set 7 | khrebtovaya
# Processing Record 31 of Set 7 | nanortalik
# Processing Record 32 of Set 7 | cavalcante
# Processing Record 33 of Set 7 | lazurne
# Processing Record 34 of Set 7 | bilma
# Processing Record 35 of Set 7 | gold coast
# Processing Record 36 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 7 | koulamoutou
# Processing Record 38 of Set 7 | qaqortoq
# Processing Record 39 of Set 7 | cockburn town
# Processing Record 40 of Set 7 | umm lajj
# Processing Record 41 of Set 7 | togur
# Processing Record 42 of Set 7 | yulara
# Processing Record 43 of Set 7 | awbari
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 7 | channel-port aux basques
# Processing Record 47 of Set 7 | male
# Processing Record 48 of Set 7 | airai
# Processing Record 49 of Set 7 | biloela
# Processing Record 50 of Set 7 | hay river
# Processing Record 1 of Set 8 | samoylovka
# Processing Record 2 of Set 8 | pedernales
# Processing Record 3 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 8 | genhe
# Processing Record 5 of Set 8 | curup
# Processing Record 6 of Set 8 | dunedin
# Processing Record 7 of Set 8 | peleduy
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 8 | solnechnyy
# Processing Record 12 of Set 8 | la palma
# Processing Record 13 of Set 8 | huanren
# Processing Record 14 of Set 8 | athabasca
# Processing Record 15 of Set 8 | zhanaozen
# Processing Record 16 of Set 8 | kachiry
# Processing Record 17 of Set 8 | anadyr
# Processing Record 18 of Set 8 | bubaque
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 8 | asfi
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 25 of Set 8 | lachi
# Processing Record 26 of Set 8 | santa
# Processing Record 27 of Set 8 | asmara
# Processing Record 28 of Set 8 | thompson
# Processing Record 29 of Set 8 | oranjemund
# Processing Record 30 of Set 8 | jiayuguan
# Processing Record 31 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 8 | comarapa
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 8 | havre-saint-pierre
# Processing Record 37 of Set 8 | esterhazy
# Processing Record 38 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 8 | ola
# Processing Record 40 of Set 8 | le port
# Processing Record 41 of Set 8 | sechura
# Processing Record 42 of Set 8 | salalah
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | blind river
# Processing Record 45 of Set 8 | canala
# Processing Record 46 of Set 8 | ndola
# Processing Record 47 of Set 8 | connersville
# Processing Record 48 of Set 8 | guerrero negro
# Processing Record 49 of Set 8 | ugoofaaru
# Processing Record 50 of Set 8 | kavieng
# Processing Record 1 of Set 9 | batesville
# Processing Record 2 of Set 9 | taga dzong
# City not found. Skipping...
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | geeste
# Processing Record 5 of Set 9 | jaguaruana
# Processing Record 6 of Set 9 | porto novo
# Processing Record 7 of Set 9 | xining
# Processing Record 8 of Set 9 | quatre cocos
# Processing Record 9 of Set 9 | sakakah
# Processing Record 10 of Set 9 | wajir
# Processing Record 11 of Set 9 | rehoboth
# Processing Record 12 of Set 9 | lakes entrance
# Processing Record 13 of Set 9 | igatpuri
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | cuneo
# Processing Record 16 of Set 9 | oriximina
# Processing Record 17 of Set 9 | shakawe
# Processing Record 18 of Set 9 | namie
# Processing Record 19 of Set 9 | goure
# Processing Record 20 of Set 9 | sikasso
# Processing Record 21 of Set 9 | asau
# Processing Record 22 of Set 9 | manggar
# Processing Record 23 of Set 9 | joshimath
# Processing Record 24 of Set 9 | sarkand
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | nome
# Processing Record 27 of Set 9 | dongsheng
# Processing Record 28 of Set 9 | rio bueno
# Processing Record 29 of Set 9 | mecca
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | mattru
# Processing Record 32 of Set 9 | sinop
# Processing Record 33 of Set 9 | krasna
# Processing Record 34 of Set 9 | kamaishi
# Processing Record 35 of Set 9 | ixtapa
# Processing Record 36 of Set 9 | mehamn
# Processing Record 37 of Set 9 | ascension
# Processing Record 38 of Set 9 | atar
# Processing Record 39 of Set 9 | eydhafushi
# Processing Record 40 of Set 9 | linares
# Processing Record 41 of Set 9 | kahului
# Processing Record 42 of Set 9 | moerai
# Processing Record 43 of Set 9 | glace bay
# Processing Record 44 of Set 9 | alta floresta
# Processing Record 45 of Set 9 | kattivakkam
# Processing Record 46 of Set 9 | talnakh
# Processing Record 47 of Set 9 | viedma
# Processing Record 48 of Set 9 | kailua
# Processing Record 49 of Set 9 | escanaba
# Processing Record 50 of Set 9 | formosa
# Processing Record 1 of Set 10 | chara
# Processing Record 2 of Set 10 | eyl
# Processing Record 3 of Set 10 | xichang
# Processing Record 4 of Set 10 | trelew
# Processing Record 5 of Set 10 | altay
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | pa sang
# Processing Record 8 of Set 10 | alegrete
# Processing Record 9 of Set 10 | axim
# Processing Record 10 of Set 10 | vao
# Processing Record 11 of Set 10 | wilmington
# Processing Record 12 of Set 10 | bressuire
# Processing Record 13 of Set 10 | chenghai
# Processing Record 14 of Set 10 | hofn
# Processing Record 15 of Set 10 | zumarraga
# Processing Record 16 of Set 10 | konigs wusterhausen
# Processing Record 17 of Set 10 | inhambane
# Processing Record 18 of Set 10 | fairbanks
# Processing Record 19 of Set 10 | simala
# Processing Record 20 of Set 10 | matay
# Processing Record 21 of Set 10 | keti bandar
# Processing Record 22 of Set 10 | sabzevar
# Processing Record 23 of Set 10 | suntar
# Processing Record 24 of Set 10 | morlaix
# Processing Record 25 of Set 10 | cherskiy
# Processing Record 26 of Set 10 | iskateley
# Processing Record 27 of Set 10 | the valley
# Processing Record 28 of Set 10 | sapa
# Processing Record 29 of Set 10 | tazovskiy
# Processing Record 30 of Set 10 | boende
# Processing Record 31 of Set 10 | sharjah
# Processing Record 32 of Set 10 | paracuru
# Processing Record 33 of Set 10 | ormstown
# Processing Record 34 of Set 10 | uige
# Processing Record 35 of Set 10 | jalingo
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 10 | hornepayne
# Processing Record 39 of Set 10 | sobolevo
# Processing Record 40 of Set 10 | ostersund
# Processing Record 41 of Set 10 | dickinson
# Processing Record 42 of Set 10 | lumeje
# Processing Record 43 of Set 10 | half moon bay
# Processing Record 44 of Set 10 | moose factory
# Processing Record 45 of Set 10 | baherden
# Processing Record 46 of Set 10 | tawzar
# City not found. Skipping...
# Processing Record 47 of Set 10 | donghai
# Processing Record 48 of Set 10 | wanaka
# Processing Record 49 of Set 10 | itarema
# Processing Record 50 of Set 10 | san ramon
# Processing Record 1 of Set 11 | chernyshevskiy
# Processing Record 2 of Set 11 | kiruna
# Processing Record 3 of Set 11 | sincai
# Processing Record 4 of Set 11 | loei
# Processing Record 5 of Set 11 | kamina
# Processing Record 6 of Set 11 | taoudenni
# Processing Record 7 of Set 11 | plessisville
# Processing Record 8 of Set 11 | batagay-alyta
# Processing Record 9 of Set 11 | gainesville
# Processing Record 10 of Set 11 | yumen
# Processing Record 11 of Set 11 | doha
# Processing Record 12 of Set 11 | tabou
# Processing Record 13 of Set 11 | turukhansk
# Processing Record 14 of Set 11 | el dovio
# Processing Record 15 of Set 11 | san juan
# Processing Record 16 of Set 11 | karlshamn
# Processing Record 17 of Set 11 | eureka
# Processing Record 18 of Set 11 | dzoragyukh
# City not found. Skipping...
# Processing Record 19 of Set 11 | lasa
# Processing Record 20 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 11 | north bend
# Processing Record 22 of Set 11 | batemans bay
# Processing Record 23 of Set 11 | kokoda
# Processing Record 24 of Set 11 | neiafu
# Processing Record 25 of Set 11 | whitecourt
# Processing Record 26 of Set 11 | beaufort
# Processing Record 27 of Set 11 | jammu
# Processing Record 28 of Set 11 | wattegama
# Processing Record 29 of Set 11 | namanga
# Processing Record 30 of Set 11 | stornoway
# Processing Record 31 of Set 11 | kerrville
# Processing Record 32 of Set 11 | shuyskoye
# Processing Record 33 of Set 11 | port macquarie
# Processing Record 34 of Set 11 | port hedland
# Processing Record 35 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 36 of Set 11 | muncar
# Processing Record 37 of Set 11 | orlik
# Processing Record 38 of Set 11 | deskati
# Processing Record 39 of Set 11 | auki
# Processing Record 40 of Set 11 | kavaratti
# Processing Record 41 of Set 11 | tanabe
# Processing Record 42 of Set 11 | gimli
# Processing Record 43 of Set 11 | zyryanka
# Processing Record 44 of Set 11 | santa isabel do rio negro
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 11 | egersund
# Processing Record 48 of Set 11 | acapulco
# Processing Record 49 of Set 11 | terrace bay
# Processing Record 50 of Set 11 | dieppe
# Processing Record 1 of Set 12 | igarka
# Processing Record 2 of Set 12 | luena
# Processing Record 3 of Set 12 | rodeo
# Processing Record 4 of Set 12 | memmingen
# Processing Record 5 of Set 12 | kudahuvadhoo
# Processing Record 6 of Set 12 | guaruja
# Processing Record 7 of Set 12 | saint-ambroise
# Processing Record 8 of Set 12 | korostyshiv
# Processing Record 9 of Set 12 | hudson bay
# Processing Record 10 of Set 12 | tambura
# Processing Record 11 of Set 12 | vangaindrano
# Processing Record 12 of Set 12 | kununurra
# Processing Record 13 of Set 12 | culipapa
# City not found. Skipping...
# Processing Record 14 of Set 12 | imeni poliny osipenko
# Processing Record 15 of Set 12 | clyde river
# Processing Record 16 of Set 12 | kawalu
# Processing Record 17 of Set 12 | kiama
# Processing Record 18 of Set 12 | dawson
# Processing Record 19 of Set 12 | kurchum
# Processing Record 20 of Set 12 | marang
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | atlantic city
# Processing Record 23 of Set 12 | nizhnekamsk
# Processing Record 24 of Set 12 | praia da vitoria
# Processing Record 25 of Set 12 | coquimbo
# Processing Record 26 of Set 12 | bintulu
# Processing Record 27 of Set 12 | cairns
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | nuuk
# Processing Record 30 of Set 12 | pacific grove
# Processing Record 31 of Set 12 | saint-avertin
# Processing Record 32 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 12 | pitimbu
# Processing Record 34 of Set 12 | bom jardim
# Processing Record 35 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 12 | coihaique
# Processing Record 37 of Set 12 | baneasa
# Processing Record 38 of Set 12 | cervo
# Processing Record 39 of Set 12 | rennes
# Processing Record 40 of Set 12 | sungaipenuh
# Processing Record 41 of Set 12 | bathurst
# Processing Record 42 of Set 12 | hammerfest
# Processing Record 43 of Set 12 | bam
# Processing Record 44 of Set 12 | jackson
# Processing Record 45 of Set 12 | leshukonskoye
# Processing Record 46 of Set 12 | shimanovsk
# Processing Record 47 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 12 | bosaso
# Processing Record 49 of Set 12 | kupang
# Processing Record 50 of Set 12 | saint-junien
# Processing Record 1 of Set 13 | kautokeino
# Processing Record 2 of Set 13 | rio novo
# Processing Record 3 of Set 13 | caarapo
# Processing Record 4 of Set 13 | moses lake
# Processing Record 5 of Set 13 | belaya gora
# Processing Record 6 of Set 13 | koumac
# Processing Record 7 of Set 13 | williamsburg
# Processing Record 8 of Set 13 | muroto
# Processing Record 9 of Set 13 | vung tau
# Processing Record 10 of Set 13 | makkaveyevo
# Processing Record 11 of Set 13 | constitucion
# Processing Record 12 of Set 13 | benalla
# Processing Record 13 of Set 13 | westport
# Processing Record 14 of Set 13 | manta
# Processing Record 15 of Set 13 | manono
# Processing Record 16 of Set 13 | ariquemes
# Processing Record 17 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 13 | nizhnevartovsk
# Processing Record 19 of Set 13 | bilibino
# Processing Record 20 of Set 13 | omboue
# Processing Record 21 of Set 13 | souillac
# Processing Record 22 of Set 13 | punto fijo
# Processing Record 23 of Set 13 | santa maria
# Processing Record 24 of Set 13 | lexington
# Processing Record 25 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 26 of Set 13 | primorsk
# Processing Record 27 of Set 13 | bambanglipuro
# Processing Record 28 of Set 13 | nioro
# Processing Record 29 of Set 13 | evensk
# Processing Record 30 of Set 13 | sur
# Processing Record 31 of Set 13 | nanchang
# Processing Record 32 of Set 13 | baoqing
# Processing Record 33 of Set 13 | nyurba
# Processing Record 34 of Set 13 | muzaffarabad
# Processing Record 35 of Set 13 | cap malheureux
# Processing Record 36 of Set 13 | mogocha
# Processing Record 37 of Set 13 | sirnak
# Processing Record 38 of Set 13 | alice springs
# Processing Record 39 of Set 13 | halifax
# Processing Record 40 of Set 13 | polyarnyy
# Processing Record 41 of Set 13 | fort nelson
# Processing Record 42 of Set 13 | sukhodol
# Processing Record 43 of Set 13 | carutapera
# Processing Record 44 of Set 13 | marsabit
# Processing Record 45 of Set 13 | revelstoke
# Processing Record 46 of Set 13 | mooresville
# Processing Record 47 of Set 13 | yaan
# Processing Record 48 of Set 13 | iquitos
# Processing Record 49 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 13 | ancud
# Processing Record 1 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 14 | codajas
# Processing Record 3 of Set 14 | itamaraca
# Processing Record 4 of Set 14 | dukat
# Processing Record 5 of Set 14 | durazno
# Processing Record 6 of Set 14 | nishihara
# Processing Record 7 of Set 14 | del rio
# Processing Record 8 of Set 14 | dakoro
# Processing Record 9 of Set 14 | mtwara
# Processing Record 10 of Set 14 | rzhev
# Processing Record 11 of Set 14 | noumea
# Processing Record 12 of Set 14 | verkhnyaya inta
# Processing Record 13 of Set 14 | kyaikkami
# Processing Record 14 of Set 14 | moyobamba
# Processing Record 15 of Set 14 | polessk
# Processing Record 16 of Set 14 | sena madureira
# Processing Record 17 of Set 14 | anderson
# Processing Record 18 of Set 14 | ca mau
# Processing Record 19 of Set 14 | awjilah
# Processing Record 20 of Set 14 | baykit
# Processing Record 21 of Set 14 | alenquer
# Processing Record 22 of Set 14 | west bay
# Processing Record 23 of Set 14 | brae
# Processing Record 24 of Set 14 | koboko
# Processing Record 25 of Set 14 | zalegoshch
# Processing Record 26 of Set 14 | mvangue
# Processing Record 27 of Set 14 | prince rupert
# Processing Record 28 of Set 14 | cabadiangan
# Processing Record 29 of Set 14 | menongue
# Processing Record 30 of Set 14 | dubbo
# Processing Record 31 of Set 14 | kijang
# Processing Record 32 of Set 14 | nacala
# Processing Record 33 of Set 14 | samoded
# Processing Record 34 of Set 14 | ambanja
# Processing Record 35 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 14 | clearwater
# Processing Record 37 of Set 14 | pochutla
# Processing Record 38 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 14 | gboko
# Processing Record 40 of Set 14 | marsa matruh
# Processing Record 41 of Set 14 | huangmei
# Processing Record 42 of Set 14 | matadi
# Processing Record 43 of Set 14 | churapcha
# Processing Record 44 of Set 14 | charters towers
# Processing Record 45 of Set 14 | andenes
# Processing Record 46 of Set 14 | vengerovo
# Processing Record 47 of Set 14 | aswan
# Processing Record 48 of Set 14 | isilkul
# Processing Record 49 of Set 14 | chhuikhadan
# Processing Record 50 of Set 14 | sorland
# Processing Record 1 of Set 15 | okha
# Processing Record 2 of Set 15 | huaihua
# Processing Record 3 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 4 of Set 15 | derzhavinsk
# Processing Record 5 of Set 15 | chegdomyn
# Processing Record 6 of Set 15 | dong hoi
# Processing Record 7 of Set 15 | lae
# Processing Record 8 of Set 15 | zharkent
# Processing Record 9 of Set 15 | sitrah
# Processing Record 10 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 11 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 15 | sorong
# Processing Record 13 of Set 15 | ponta delgada
# Processing Record 14 of Set 15 | mandurah
# Processing Record 15 of Set 15 | puerto del rosario
# Processing Record 16 of Set 15 | nouakchott
# Processing Record 17 of Set 15 | namibe
# Processing Record 18 of Set 15 | kieta
# Processing Record 19 of Set 15 | deqing
# Processing Record 20 of Set 15 | otradnoye
# Processing Record 21 of Set 15 | vestmannaeyjar
# Processing Record 22 of Set 15 | mandalgovi
# Processing Record 23 of Set 15 | kloulklubed
# Processing Record 24 of Set 15 | centralia
# Processing Record 25 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 15 | puerto leguizamo
# Processing Record 27 of Set 15 | shahr-e babak
# Processing Record 28 of Set 15 | campobasso
# Processing Record 29 of Set 15 | katiola
# Processing Record 30 of Set 15 | valencia
# Processing Record 31 of Set 15 | algiers
# Processing Record 32 of Set 15 | swift current
# Processing Record 33 of Set 15 | monroe
# Processing Record 34 of Set 15 | penugonda
# Processing Record 35 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 15 | dagua
# Processing Record 37 of Set 15 | opuwo
# Processing Record 38 of Set 15 | cacu
# Processing Record 39 of Set 15 | ajdabiya
# Processing Record 40 of Set 15 | rapid valley
# Processing Record 41 of Set 15 | mwinilunga
# Processing Record 42 of Set 15 | balkhash
# Processing Record 43 of Set 15 | srednekolymsk
# Processing Record 44 of Set 15 | terrace
# Processing Record 45 of Set 15 | labuan
# Processing Record 46 of Set 15 | prainha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Chokurdakh  70.6333  147.9167    -48.71       100          67
# 1       Mbarara  -0.6080   30.6500     64.94        89          94
# 2     Esperance -33.8667  121.9000     58.84        76           0
# 3       Dingtao  35.0683  115.5625     46.11        83         100
# 4      Hermanus -34.4187   19.2345     70.90        68          86
# 5         Bluff -46.6000  168.3333     44.80        65           7
# 6  Ponta Do Sol  32.6667  -17.1000     66.83        59          24
# 7     Busselton -33.6500  115.3333     56.08        83          49
# 8   New Norfolk -42.7826  147.0587     49.71        62          90
# 9       Ushuaia -54.8000  -68.3000     60.46        48          40
#
#    Wind Speed Current Description Country
# 0        2.35       broken clouds      RU
# 1        2.93          light rain      UG
# 2       12.50           clear sky      AU
# 3        5.06     overcast clouds      CN
# 4       20.65     overcast clouds      ZA
# 5        6.15           clear sky      NZ
# 6        7.18          few clouds      PT
# 7       12.19    scattered clouds      AU
# 8        1.23     overcast clouds      AU
# 9       10.36    scattered clouds      AR

# %%
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_city_data_df]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Chokurdakh      RU  70.6333  147.9167    -48.71       100          67
# 1       Mbarara      UG  -0.6080   30.6500     64.94        89          94
# 2     Esperance      AU -33.8667  121.9000     58.84        76           0
# 3       Dingtao      CN  35.0683  115.5625     46.11        83         100
# 4      Hermanus      ZA -34.4187   19.2345     70.90        68          86
# 5         Bluff      NZ -46.6000  168.3333     44.80        65           7
# 6  Ponta Do Sol      PT  32.6667  -17.1000     66.83        59          24
# 7     Busselton      AU -33.6500  115.3333     56.08        83          49
# 8   New Norfolk      AU -42.7826  147.0587     49.71        62          90
# 9       Ushuaia      AR -54.8000  -68.3000     60.46        48          40
#
#    Wind Speed Current Description
# 0        2.35       broken clouds
# 1        2.93          light rain
# 2       12.50           clear sky
# 3        5.06     overcast clouds
# 4       20.65     overcast clouds
# 5        6.15           clear sky
# 6        7.18          few clouds
# 7       12.19    scattered clouds
# 8        1.23     overcast clouds
# 9       10.36    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
